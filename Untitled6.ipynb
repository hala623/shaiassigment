# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import missingno as msno


data=pd.read_csv('/content/Salaries.csv')


data.hist(bins=50, figsize=(20,15))
plt.show()

# %%
print(data.describe())
# Out:
#                  Id        BasePay    OvertimePay       OtherPay  \
# count  116479.00000  115874.000000  116479.000000  116479.000000
# mean    58240.00000   69711.777605    5552.186954    4049.761005
# std     33624.73534   44304.895794   12366.738794    8645.226043
# min         1.00000    -166.010000      -0.010000   -7058.590000
# 25%     29120.50000   38138.595000       0.000000       0.000000
# 50%     58240.00000   66624.240000       0.000000     945.840000
# 75%     87359.50000  100736.977500    5165.330000    4832.735000
# max    116479.00000  319275.010000  245131.880000  400184.250000
#
#            Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  80320.000000  116478.000000     116478.000000  116478.000000    0.0
# mean   26589.464793   78951.203789      97286.561318    2012.114537    NaN
# std    15704.939751   52805.115553      65358.466062       0.907971    NaN
# min      -33.890000       0.000000        -33.890000    2011.000000    NaN
# ...

# %%
print(data["Year"].value_counts())
print(data["Agency"].value_counts())
# Out:
# 2013.0    37606
# 2012.0    36766
# 2011.0    36159
# 2014.0     5947
# Name: Year, dtype: int64
# San Francisco    116478
# Name: Agency, dtype: int64

# %%
corr_matrix = data.corr(numeric_only = True)
print(corr_matrix)
# Out:
#                         Id   BasePay  OvertimePay  OtherPay  Benefits  \
# Id                1.000000 -0.096627    -0.018409 -0.037786 -0.296349
# BasePay          -0.096627  1.000000     0.263227  0.293580  0.918347
# OvertimePay      -0.018409  0.263227     1.000000  0.322189  0.290880
# OtherPay         -0.037786  0.293580     0.322189  1.000000  0.241160
# Benefits         -0.296349  0.918347     0.290880  0.241160  1.000000
# TotalPay         -0.100840  0.951320     0.510190  0.482766  0.880021
# TotalPayBenefits  0.035513  0.941996     0.473658  0.437638  0.926237
# Year              0.947356  0.210378     0.122206  0.092652  0.146809
# Notes                  NaN       NaN          NaN       NaN       NaN
# Status                 NaN       NaN          NaN       NaN       NaN
#
#                   TotalPay  TotalPayBenefits      Year  Notes  Status
# Id               -0.100840          0.035513  0.947356    NaN     NaN
# ...

# %%
print(data.isnull().sum().sort_values(ascending=False))
print(data.info())
msno.bar(data)
# Out:
# Notes               116479
# Status              116479
# Benefits             36159
# BasePay                605
# TotalPay                 1
# TotalPayBenefits         1
# Year                     1
# Agency                   1
# Id                       0
# EmployeeName             0
# JobTitle                 0
# OvertimePay              0
# OtherPay                 0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116479 entries, 0 to 116478
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                116479 non-null  int64
#  1   EmployeeName      116479 non-null  object
#  2   JobTitle          116479 non-null  object
#  3   BasePay           115874 non-null  float64
#  4   OvertimePay       116479 non-null  float64
#  5   OtherPay          116479 non-null  float64
#  6   Benefits          80320 non-null   float64
# ...

# %%
data["TotalPay"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["TotalPayBenefits"].plot(kind="hist")
data.duplicated(keep=False).sum()
# Out:
# 0

# %%
data.loc[data["Benefits"]<0].head()
# Out:
#             Id      EmployeeName          JobTitle  BasePay  OvertimePay  \
# 110528  110529  Timothy E Gibson  Police Officer 3      NaN          0.0
# 110529  110530    Mark E Laherty  Police Officer 3      NaN          0.0
# 110530  110531     David P Kucia  Police Officer 3      NaN          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits    Year  Notes  \
# 110528       0.0     -2.73       0.0             -2.73  2013.0    NaN
# 110529       0.0     -8.20       0.0             -8.20  2013.0    NaN
# 110530       0.0    -33.89       0.0            -33.89  2013.0    NaN
#
#                Agency  Status
# 110528  San Francisco     NaN
# 110529  San Francisco     NaN
# 110530  San Francisco     NaN

# %%
data.loc[data["JobTitle"]=="Police Officer 3"	].describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count    2171.000000    2161.000000    2171.000000    2171.000000
# mean    73785.735606  111657.193957   17933.744910    9978.382423
# std     28557.905413   25488.451303   17153.777144   15503.478276
# min     36315.000000       0.000000       0.000000       0.000000
# 25%     42315.500000  117162.680000    5774.765000    3649.785000
# 50%     76471.000000  118840.990000   12233.190000    6329.720000
# 75%    103999.000000  123471.020000   25738.500000   10967.255000
# max    116473.000000  131105.100000  109310.130000  152037.570000
#
#            Benefits       TotalPay  TotalPayBenefits         Year  Notes  \
# count   2171.000000    2171.000000       2171.000000  2171.000000    0.0
# mean   33697.809456  139055.009019     172752.818475  2012.847536    NaN
# std     9206.374021   36113.696472      43692.456506     0.787733    NaN
# min      -33.890000       0.000000        -33.890000  2012.000000    NaN
# ...

# %%
data.loc[data["TotalPayBenefits"]<0]==172752.818475
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 110528  False         False     False    False        False     False
# 110529  False         False     False    False        False     False
# 110530  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# 110528     False     False             False  False  False   False   False
# 110529     False     False             False  False  False   False   False
# 110530     False     False             False  False  False   False   False

# %%
data["Benefits"].fillna(0)
# Out:
# 0             0.00
# 1             0.00
# 2             0.00
# 3             0.00
# 4             0.00
#             ...
# 116474    37090.74
# 116475    39786.42
# 116476    31807.57
# 116477    38429.44
# 116478       38.00
# Name: Benefits, Length: 116479, dtype: float64

# %%
data.groupby("Year").apply(lambda rows:(rows ["TotalPayBenefits"]==567595.430000).sum()).sort_values(ascending=False).head()
# Out:
# Year
# 2011.0    1
# 2012.0    0
# 2013.0    0
# 2014.0    0
# dtype: int64

# %%
data.loc[data["Year"]==2011	].describe()
# Out:
#                  Id        BasePay    OvertimePay       OtherPay  Benefits  \
# count  36159.000000   36159.000000   36159.000000   36159.000000       0.0
# mean   18080.000000   63595.956517    4531.065429    3617.081926       NaN
# std    10438.348528   40556.774993   10501.367793    7959.889157       NaN
# min        1.000000       0.000000       0.000000       0.000000       NaN
# 25%     9040.500000   33468.125000       0.000000       0.000000       NaN
# 50%    18080.000000   62871.720000       0.000000     795.600000       NaN
# 75%    27119.500000   90649.765000    4215.040000    4057.730000       NaN
# max    36159.000000  294580.020000  245131.880000  400184.250000       NaN
#
#             TotalPay  TotalPayBenefits     Year  Notes  Status
# count   36159.000000      36159.000000  36159.0    0.0     0.0
# mean    71744.103871      71744.103871   2011.0    NaN     NaN
# std     47498.706594      47498.706594      0.0    NaN     NaN
# ...

# %%
data.loc[data["Year"]==2012	].describe()
# Out:
#                  Id        BasePay    OvertimePay       OtherPay  \
# count  36766.000000   36766.000000   36766.000000   36766.000000
# mean   54542.500000   65436.406857    5023.417824    3653.437583
# std    10613.574335   41782.209797   11431.885357    7936.873235
# min    36160.000000    -166.010000       0.000000       0.000000
# 25%    45351.250000   34036.580000       0.000000       9.722500
# 50%    54542.500000   64017.370000       0.000000     920.645000
# 75%    63733.750000   92427.927500    4691.610000    4339.382500
# max    72925.000000  302578.000000  220909.480000  245999.410000
#
#            Benefits       TotalPay  TotalPayBenefits     Year  Notes  Status
# count  36766.000000   36766.000000      36766.000000  36766.0    0.0     0.0
# mean   26439.966967   74113.262265     100553.229232   2012.0    NaN     NaN
# std    15624.924375   49523.904319      63555.796681      0.0    NaN     NaN
# ...

# %%
data.loc[data["Year"]==2013	].describe()
# Out:
#                   Id        BasePay   OvertimePay       OtherPay  \
# count   37606.000000   37001.000000   37606.00000   37606.000000
# mean    91728.500000   69630.030216    5281.64198    3819.969007
# std     10856.061448   44237.113207   11998.99504    8536.254718
# min     72926.000000      15.830000      -0.01000   -7058.590000
# 25%     82327.250000   37021.500000       0.00000       0.000000
# 50%     91728.500000   67669.000000       0.00000     792.060000
# 75%    101129.750000   98272.550000    4707.77000    4448.482500
# max    110531.000000  319275.010000  196689.18000  202322.370000
#
#            Benefits       TotalPay  TotalPayBenefits     Year  Notes  Status
# count  37606.000000   37606.000000      37606.000000  37606.0    0.0     0.0
# mean   23829.076572   77611.443142     101440.519714   2013.0    NaN     NaN
# std    14749.075693   52854.774783      66390.034642      0.0    NaN     NaN
# ...

# %%
data.loc[data["Year"]==2014	].describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count    5947.000000    5947.000000    5947.000000    5947.000000
# mean   113505.000000  133829.044740   16741.231940   10583.100126
# std      1716.895357   28739.372918   21746.827112   13539.687621
# min    110532.000000   20465.010000       0.000000       0.000000
# 25%    112018.500000  114403.465000       0.000000    1432.140000
# 50%    113505.000000  129725.560000    8001.880000    8072.160000
# 75%    114991.500000  143566.480000   27123.990000   16126.240000
# max    116478.000000  318835.490000  173547.730000  342802.630000
#
#            Benefits       TotalPay  TotalPayBenefits    Year  Notes  Status
# count   5947.000000    5947.000000       5947.000000  5947.0    0.0     0.0
# mean   44973.548867  161153.376807     206126.925673  2014.0    NaN     NaN
# std     7739.074054   28966.479056      33427.800272     0.0    NaN     NaN
# ...

# %% [markdown]
# I started with a quick visualization using hist() which makes the data easier to understand conceptually and gives you a clear view
# data.dscribe
# How to show all basic statistics for mean, median, mode, minimum and maximum salary,
# The data shows a range of salaries between the years 2011, 2012, 2013 and 2014, “which have the least amount of data,” at the San Francisco agency. Data were presented in more than one way to account for missing values.
# The Benefits column has a large portion of missing values ​​that I filled with 0
# I focused on the Total Wages/Benefits columns which represent total salaries. The corr() method calculates the relationship between each column in your data set. The correlation coefficient ranges from -1 to 1. to show the relationship between each two attributes
#  You have checked for invalid values ​​and filled them with appropriate values

# %% [markdown]
# Then I displayed the statistical data for each “year” group to compare each year to the other
